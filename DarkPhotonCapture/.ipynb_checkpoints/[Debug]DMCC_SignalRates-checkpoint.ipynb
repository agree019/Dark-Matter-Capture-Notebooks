# %% [markdown]
# # Signal Rate Plots

# %% [markdown]
# This notebook outputs the reach plots in $\varepsilon - m_A$ space for IceCube.
#
# Upon running this notebook the first time, run each cell sequentially. If however, you have started a calculation and now wish to continue where you left off, begin at the "External File Interpolations" cell and continue onward.

# %% [markdown]
# ## Import Notebook as module

# %%
import io, os, sys, types

from IPython import get_ipython
from nbformat import read
from IPython.core.interactiveshell import InteractiveShell

def find_notebook(fullname, path=None):
    """find a notebook, given its fully qualified name and an optional path

    This turns "foo.bar" into "foo/bar.ipynb"
    and tries turning "Foo_Bar" into "Foo Bar" if Foo_Bar
    does not exist.
    """
    name = fullname.rsplit('.', 1)[-1]
    if not path:
        path = ['']
    for d in path:
        nb_path = os.path.join(d, name + ".ipynb")
        if os.path.isfile(nb_path):
            return nb_path
        # let import Notebook_Name find "Notebook Name.ipynb"
        nb_path = nb_path.replace("_", " ")
        if os.path.isfile(nb_path):
            return nb_path
        
class NotebookLoader(object):
    """Module Loader for Jupyter Notebooks"""
    def __init__(self, path=None):
        self.shell = InteractiveShell.instance()
        self.path = path

    def load_module(self, fullname):
        """import a notebook as a module"""
        path = find_notebook(fullname, self.path)

        print ("importing Jupyter notebook from %s" % path)

        # load the notebook object
        with io.open(path, 'r', encoding='utf-8') as f:
            nb = read(f, 4)


        # create the module and add it to sys.modules
        # if name in sys.modules:
        #    return sys.modules[name]
        mod = types.ModuleType(fullname)
        mod.__file__ = path
        mod.__loader__ = self
        mod.__dict__['get_ipython'] = get_ipython
        sys.modules[fullname] = mod

        # extra work to ensure that magics that would affect the user_ns
        # actually affect the notebook module's ns
        save_user_ns = self.shell.user_ns
        self.shell.user_ns = mod.__dict__

        try:
            for cell in nb.cells:
                if cell.cell_type == 'code':
                    # transform the input to executable Python
                    code = self.shell.input_transformer_manager.transform_cell(cell.source)
                    # run the code in themodule
                    exec(code, mod.__dict__)
        finally:
            self.shell.user_ns = save_user_ns
        return mod

    
class NotebookFinder(object):
    """Module finder that locates Jupyter Notebooks"""
    def __init__(self):
        self.loaders = {}

    def find_module(self, fullname, path=None):
        nb_path = find_notebook(fullname, path)
        if not nb_path:
            return

        key = path
        if path:
            # lists aren't hashable
            key = os.path.sep.join(path)

        if key not in self.loaders:
            self.loaders[key] = NotebookLoader(path)
        return self.loaders[key]
    
sys.meta_path.append(NotebookFinder())

print ('Complete')
# Out:
# Complete

# %%
from MasterFunctions_SignalRates import *
from MasterFunctions_Graphing import*

print ('All Notebooks Imported')
# Out:
# importing Jupyter notebook from MasterFunctions_SignalRates.ipynb
# importing Jupyter notebook from MasterFunctions_Capture.ipynb
# importing Jupyter notebook from MasterFunctions_ModelData.ipynb
# ------ MasterFunctions_ModelData Imported ------
# ------ MasterFunctions_Capture Loaded ------
# importing Jupyter notebook from MasterFunctions_Annihilation.ipynb
# ------ MasterFunctions_Annihilation Loaded ------
# ------ MasterFunctions_SignalRates Imported ------
# importing Jupyter notebook from MasterFunctions_Graphing.ipynb
# ------ MasterFunctions_Graphing Loaded ------
# All Notebooks Imported

# %% [markdown]
# # Signal Rate

# %% [markdown]
# Recall the solution to the differential equation:
# \begin{equation}
# \frac{dN_X}{dt} = C_{cap} - N_X^2 C_{ann}
# \end{equation}
#
# is given by:
#
# \begin{equation}
# \Gamma_{ann} = \frac{1}{2} C_{cap}\tanh^2 \left( \frac{\tau_{\oplus}}{\tau} \right)
# \end{equation}
#
# more stuff about the signal rate

# %% [markdown]
# -------------

# %% [markdown]
# # Generating the Signal Data File

# %% [markdown]
# ## Recipie

# %% [markdown]
# The recipie for generating the Signal File is:
#
# 1). Generate a Template Dataframe
#
# 2). Write that Dataframe to an external .csv file
#
# 3). Read in and interpolate the Branching Ratio for a given process and the Sommerfeld enhancement
#
# 4). Calculate $C_{Cap}$, $C_{Ann}$, $\Gamma_{Ann}$, and $N_{Sig}$ and append them to the signal .csv file.
#
# Step four can be quite lengthy depending on the desired resultioin on the data points. Typically, one would begin these calculations and be forced to wait until they are completed in their entirety; perhaps unable to shut down their machine for hours at a time. The cell "Signal File Calculations" however can be interrupted at any time, and resumed later. This allows the user to run the calculation in multiple stages instead of dedicating a large chunk of time and running the calculation all at once.
# The calculation can be stopped by interrupting the Jupyter Kernel. Be sure to run the "Manual Overwrite" cell just to be sure that the calculations are saved.

# %% [markdown]
# ## Initialize External Signal File

# %% [markdown]
# These cells create the "grid" of data points for which $N_{sig}$ will be calculated.

# %% [markdown]
# ### Initialize Data Ranges

# %%
num = 200

# %%
#########################################
# Define parameter space Ranges
#########################################
# Logarithmic Spacing
mALogRange = np.logspace(-2, 1, num, base = 10)
epsilonLogRange = np.logspace(-10, -5, num, base = 10)


#########################################
# Initialize Master Arrays
#########################################
masterSignalArray = []

#########################################
# Populate the Master Arrays with the column headers and 'None' Cells
#########################################
counter = 0
for mATemp in mALogRange:
    for epsilonTemp in epsilonLogRange:
        masterSignalArray.append([counter, ' ', mATemp, epsilonTemp, \
                                  'None', 'None', 'None', 'None', ' '])
        counter += 1

        
#########################################
# Create a PANDAS DataFrame from the Master Arrays
#########################################
masterSignalDataframe = pd.DataFrame(data = masterSignalArray, \
    columns=['Counter', 'mX[GeV]', 'mA[GeV]', 'Epsilon',\
             'Capture', 'Annihilation', 'GammaAnn', 'IceCubeSignal', 'Kappa0'])

print ('Complete')
# Out:
# Complete

# %% [markdown]
# ### Write to External .csv File

# %%
SignalFile = input('Signal Rate filename: ')

writeFile = signalDataPath(SignalFile)

# Append a single value onto the Kappa0 Column
kappa0Value = 'None'
m_XValue = 'None'
masterSignalDataframe.set_value(0, 'mX[GeV]', m_XValue)
masterSignalDataframe.set_value(0, 'Kappa0' , kappa0Value)

masterSignalDataframe.to_csv(writeFile, index=False)

print ('Complete')
# Out:
# Signal Rate filename: 10TeVSignal.csv
# Complete

# %% [markdown]
# ## External File Interpolations

# %% [markdown]
# The following cells read in and create interpolations of the:
#
# 1). Branching ratio
#
# 2). Sommerfeld Enhancement
#
# The branching ratio data is stored in a folder called "BranchingRatioData."
#
# The Sommerfeld data, which has been calculated prior, is stored in the folder "Sommerfeld Data."

# %% [markdown]
# ### Branching Ratio Interpolation

# %% [markdown]
# In this cell, we read in a .csv file containing discrete branching ratio data points obtained from WebPlotDigitizer and interpolate them into a continuous funciton named "branchRatioInterp."

# %%
# branchFile = input('Branching File: ')
branchFile = 'brtoeAdam.csv'

BranchData = pd.read_csv(branchPath(branchFile))

xList = BranchData['mA[GeV]']
yList = BranchData['BR']

branchRatioInterp = interpolate.interp1d(xList,yList)

print ('Complete')
# Out:
# Complete

# %% [markdown]
# ### Sommerfeld Data Interpolation

# %% [markdown]
# The following two cells read in an external Sommerfeld data file and:
#
# 1). Append the m_X value defined in the Sommerfeld file to the Signal file
#
# 2). Append the Kappa0 value defined in the Sommerfeld file to the Signal File
#
# 3). Interpolate the discrete set of ($m_A$, $\langle S_s \rangle$) points into a continuous function $\langle S_s \rangle(m_A)$

# %%
####################################
# Define Sommerfeld and Signal Files
####################################
SommName = input('Sommerfeld File: ')
SommFile = pd.read_csv(sommerfeldPath(SommName))
filename = input('Signal Rate File: ')
writeFile = signalDataPath(filename)
dataFrame = pd.read_csv(writeFile , sep = ',')

####################################
# Append Sommerfeld data
####################################
testm_X = dataFrame.loc[0,'mX[GeV]']
testKappa0 = dataFrame.loc[0, 'Kappa0']

if (testm_X == 'None'):
    SommM_X = float(SommFile.loc[0,'mX[GeV]'])
    dataFrame.set_value(0, 'mX[GeV]', SommM_X)

elif(testm_X != 'None'):
    print ('mX value already appended to Signal File')
    
if (testKappa0 == 'None'):
    SommKappa0 = float(SommFile.loc[0,'Kappa0'])
    dataFrame.set_value(0, 'Kappa0', SommKappa0)

elif (testKappa0 != 'None'):
    print ('Kappa0 value already appended to Signal File')

dataFrame.to_csv(writeFile, index=False)


####################################
# Interpolate Sommerfeld data
####################################
mAData = SommFile['mA[GeV]']
SommData = SommFile['ThermAvgSommerfeld']
SommInterp = interpolate.interp1d(mAData,SommData)
print ('Interpolation Complete')


print ('Complete')
# Out:
# Sommerfeld File: 10TeVSommerfeld.csv
# Signal Rate File: 10TeVSignal.csv
# Interpolation Complete
# Complete

# %% [markdown]
# ### Visualization of Sommerfeld Resolution

# %% [markdown]
# The following cell plots the sommerfeld enhancement given the number of data points for a single axis of the signal file. If a greater number of data points is required, under the "Initialize Data Ranges" cell, change the "num" parameter, and run the notebook to this point again.

# %%
vect1 = []
vect2 = []
for ma in np.logspace(-2,1, num, base = 10):
    vect1.append(ma)
    vect2.append(SommInterp(ma))

    
plt.plot(np.log10(vect1),np.log10(vect2))

# %% [markdown]
# ## Sanity Check

# %% [markdown]
# We expect that:
#
# 1). The $m_X$ value from the Sommerfeld file is appended to the Signal file
#
# 2). The Kappa0 value from the Sommerfeld file is appended to the Signal file
#
# 3). The Signal file has 8 columns labeled
#
#     Counter, mX[GeV], mA[GeV], Epsilon, Capture, Annihilation, GammaAnn, IceCubeSignal, Kappa0

# %%
filename = input('Signal Rate filename: ')
writeFile = signalDataPath(filename)

print (pd.read_csv(writeFile, sep = ','))
print ('Complete')
# Out:
# Signal Rate filename: 10TeVSignal.csv
#        Counter  mX[GeV]  mA[GeV]       Epsilon Capture Annihilation GammaAnn  \
# 0            0  10000.0     0.01  1.000000e-10    None         None     None
# 1            1              0.01  1.059560e-10    None         None     None
# 2            2              0.01  1.122668e-10    None         None     None
# 3            3              0.01  1.189534e-10    None         None     None
# 4            4              0.01  1.260383e-10    None         None     None
# 5            5              0.01  1.335452e-10    None         None     None
# 6            6              0.01  1.414991e-10    None         None     None
# 7            7              0.01  1.499268e-10    None         None     None
# 8            8              0.01  1.588565e-10    None         None     None
# 9            9              0.01  1.683180e-10    None         None     None
# 10          10              0.01  1.783431e-10    None         None     None
# 11          11              0.01  1.889652e-10    None         None     None
# 12          12              0.01  2.002200e-10    None         None     None
# 13          13              0.01  2.121452e-10    None         None     None
# 14          14              0.01  2.247806e-10    None         None     None
# 15          15              0.01  2.381686e-10    None         None     None
# 16          16              0.01  2.523539e-10    None         None     None
# 17          17              0.01  2.673842e-10    None         None     None
# 18          18              0.01  2.833096e-10    None         None     None
# 19          19              0.01  3.001836e-10    None         None     None
# 20          20              0.01  3.180626e-10    None         None     None
# 21          21              0.01  3.370064e-10    None         None     None
# 22          22              0.01  3.570786e-10    None         None     None
# 23          23              0.01  3.783463e-10    None         None     None
# 24          24              0.01  4.008806e-10    None         None     None
# 25          25              0.01  4.247572e-10    None         None     None
# 26          26              0.01  4.500558e-10    None         None     None
# 27          27              0.01  4.768612e-10    None         None     None
# 28          28              0.01  5.052631e-10    None         None     None
# 29          29              0.01  5.353567e-10    None         None     None
# ...        ...      ...      ...           ...     ...          ...      ...
# 39970    39970             10.00  1.867914e-06    None         None     None
# 39971    39971             10.00  1.979167e-06    None         None     None
# 39972    39972             10.00  2.097046e-06    None         None     None
# 39973    39973             10.00  2.221947e-06    None         None     None
# 39974    39974             10.00  2.354286e-06    None         None     None
# 39975    39975             10.00  2.494508e-06    None         None     None
# 39976    39976             10.00  2.643081e-06    None         None     None
# 39977    39977             10.00  2.800504e-06    None         None     None
# 39978    39978             10.00  2.967302e-06    None         None     None
# 39979    39979             10.00  3.144035e-06    None         None     None
# 39980    39980             10.00  3.331295e-06    None         None     None
# 39981    39981             10.00  3.529707e-06    None         None     None
# 39982    39982             10.00  3.739937e-06    None         None     None
# 39983    39983             10.00  3.962689e-06    None         None     None
# 39984    39984             10.00  4.198707e-06    None         None     None
# 39985    39985             10.00  4.448783e-06    None         None     None
# 39986    39986             10.00  4.713753e-06    None         None     None
# 39987    39987             10.00  4.994505e-06    None         None     None
# 39988    39988             10.00  5.291979e-06    None         None     None
# 39989    39989             10.00  5.607170e-06    None         None     None
# 39990    39990             10.00  5.941134e-06    None         None     None
# 39991    39991             10.00  6.294989e-06    None         None     None
# 39992    39992             10.00  6.669920e-06    None         None     None
# 39993    39993             10.00  7.067181e-06    None         None     None
# 39994    39994             10.00  7.488104e-06    None         None     None
# 39995    39995             10.00  7.934097e-06    None         None     None
# 39996    39996             10.00  8.406653e-06    None         None     None
# 39997    39997             10.00  8.907355e-06    None         None     None
# 39998    39998             10.00  9.437878e-06    None         None     None
# 39999    39999             10.00  1.000000e-05    None         None     None
#
#       IceCubeSignal                  Kappa0
# 0              None  3.1437639639459263e+23
# 1              None
# 2              None
# 3              None
# 4              None
# 5              None
# 6              None
# 7              None
# 8              None
# 9              None
# 10             None
# 11             None
# 12             None
# 13             None
# 14             None
# 15             None
# 16             None
# 17             None
# 18             None
# 19             None
# 20             None
# 21             None
# 22             None
# 23             None
# 24             None
# 25             None
# 26             None
# 27             None
# 28             None
# 29             None
# ...             ...                     ...
# 39970          None
# 39971          None
# 39972          None
# 39973          None
# 39974          None
# 39975          None
# 39976          None
# 39977          None
# 39978          None
# 39979          None
# 39980          None
# 39981          None
# 39982          None
# 39983          None
# 39984          None
# 39985          None
# 39986          None
# 39987          None
# 39988          None
# 39989          None
# 39990          None
# 39991          None
# 39992          None
# 39993          None
# 39994          None
# 39995          None
# 39996          None
# 39997          None
# 39998          None
# 39999          None
#
# [40000 rows x 9 columns]
# Complete

# %% [markdown]
# ## Signal File Calculations

# %% [markdown]
# This cell scans through all the lines of the .csv file and calculates:
#
# 1). Capture
#
# 2). Annihilation
#
# 3). GammaAnn
#
# 4). Signal
#
# As mentioned previously, this cell may be stopped, by interrupting the kernel, at any time and resumed later.

# %%
fileName = input('Signal Rate filename: ')
writeFile = signalDataPath(fileName)
dataIn = pd.read_csv(writeFile, sep = ',')

#########################################
# Define loop range
#########################################
# Scan down 'Counter' column, start calculating at first non-calculated value
loopRange = range(0,len(dataIn['Counter']))

#########################################
# Parameters independent of data file:
#########################################
Filem_X = float(dataIn.loc[0, 'mX[GeV]'])
FileKappa0 = float(dataIn.loc[0, 'Kappa0'])
Alpha = 1./137
LiveTime = yr2s(10)



#########################################
# Begin the loop calculations
#########################################
print (fileName)
print ()
print ('--------------------')
finishedCounter = 0
index = 0
for index in loopRange:
    testValue = dataIn.loc[index, 'IceCubeSignal']
    if (testValue == 'None'):
        
        #########################################
        # Initialize Loop Parameters
        #########################################
        Filem_ATemp = float(dataIn.loc[index, 'mA[GeV]'])
        FileEpsilonTemp = float(dataIn.loc[index, 'Epsilon'])
        Alpha_X = alphaTherm(Filem_X, Filem_ATemp)
        Sommerfeld = SommInterp(Filem_ATemp)
        BranchingRatio = branchRatioInterp(Filem_ATemp)
        
        #########################################
        # Loop Calculations
        #########################################
        Capture = CCapQuick(Filem_X, Filem_ATemp, FileEpsilonTemp, Alpha_X, FileKappa0)
        SigmaVTree = sigmaVtree(Filem_X, Filem_ATemp, Alpha_X)
        Annihilation = CAnnCalc(Filem_X, Filem_ATemp, SigmaVTree, thermAvgSomm = Sommerfeld)
        GammaAnn = gammaAnn(Capture, Annihilation)
        L = decayLength2(Filem_X, Filem_ATemp, FileEpsilonTemp, BranchingRatio)
        EpsilonDecay = epsilonDecay(L)
        
        IceCubeSignal = iceCubeSignal(GammaAnn, EpsilonDecay, LiveTime)
        
        #########################################
        # Append Calculated Values to SignalFile.csv
        #########################################
        dataIn.set_value(index, 'Capture', Capture)
        dataIn.set_value(index, 'Annihilation', Annihilation)
        dataIn.set_value(index, 'GammaAnn', GammaAnn)
        dataIn.set_value(index, 'IceCubeSignal', IceCubeSignal)
        
        
        #########################################
        # Overwrite SignalFile.csv
        #########################################
        dataIn.to_csv(writeFile, sep=',',index=False) 
        finishedCounter += 1
        
        if (index % 20 == 0):
            print ('Calculations for index: {0} recorded'.format(index))
        
    elif (testValue != 'None'):
        finishedCounter += 1
    
    if (finishedCounter == len(dataIn['Counter'])):
        print ('All Calculations Complete')
        break
        
print ('Complete')
# Out:
# Signal Rate filename: 10TeVSignal.csv
# 10TeVSignal.csv
#
# --------------------
# Calculations for index: 0 recorded
# Calculations for index: 20 recorded
# Calculations for index: 40 recorded
# Calculations for index: 60 recorded
# Calculations for index: 80 recorded
# Calculations for index: 100 recorded
# Calculations for index: 120 recorded
# Calculations for index: 140 recorded
# Calculations for index: 160 recorded
# Calculations for index: 180 recorded
# Calculations for index: 200 recorded
# Calculations for index: 220 recorded
# Calculations for index: 240 recorded
# Calculations for index: 260 recorded
# Calculations for index: 280 recorded
# Calculations for index: 300 recorded
# Calculations for index: 320 recorded
# Calculations for index: 340 recorded
# Calculations for index: 360 recorded
# Calculations for index: 380 recorded
# Calculations for index: 400 recorded
# Calculations for index: 420 recorded
# Calculations for index: 440 recorded
# Calculations for index: 460 recorded
# Calculations for index: 480 recorded
# Calculations for index: 500 recorded
# Calculations for index: 520 recorded
# Calculations for index: 540 recorded
# Calculations for index: 560 recorded
# Calculations for index: 580 recorded
# Calculations for index: 600 recorded
# Calculations for index: 620 recorded
# Calculations for index: 640 recorded
# Calculations for index: 660 recorded
# Calculations for index: 680 recorded
# Calculations for index: 700 recorded
# Calculations for index: 720 recorded
# Calculations for index: 740 recorded
# Calculations for index: 760 recorded
# Calculations for index: 780 recorded
# Calculations for index: 800 recorded
# Calculations for index: 820 recorded
# Calculations for index: 840 recorded
# Calculations for index: 860 recorded
# Calculations for index: 880 recorded
# Calculations for index: 900 recorded
# Calculations for index: 920 recorded
# Calculations for index: 940 recorded
# Calculations for index: 960 recorded
# Calculations for index: 980 recorded
# Calculations for index: 1000 recorded
# Calculations for index: 1020 recorded
# Calculations for index: 1040 recorded
# Calculations for index: 1060 recorded
# Calculations for index: 1080 recorded
# Calculations for index: 1100 recorded
# Calculations for index: 1120 recorded
# Calculations for index: 1140 recorded
# Calculations for index: 1160 recorded
# Calculations for index: 1180 recorded
# Calculations for index: 1200 recorded
# Calculations for index: 1220 recorded
# Calculations for index: 1240 recorded
# Calculations for index: 1260 recorded
# Calculations for index: 1280 recorded
# Calculations for index: 1300 recorded
# Calculations for index: 1320 recorded
# Calculations for index: 1340 recorded
# Calculations for index: 1360 recorded
# Calculations for index: 1380 recorded
# Calculations for index: 1400 recorded
# Calculations for index: 1420 recorded
# Calculations for index: 1440 recorded
# Calculations for index: 1460 recorded
# Calculations for index: 1480 recorded
# Calculations for index: 1500 recorded
# Calculations for index: 1520 recorded
# Calculations for index: 1540 recorded
# Calculations for index: 1560 recorded
# Calculations for index: 1580 recorded
# Calculations for index: 1600 recorded
# Calculations for index: 1620 recorded
# Calculations for index: 1640 recorded
# Calculations for index: 1660 recorded
# Calculations for index: 1680 recorded
# Calculations for index: 1700 recorded
# Calculations for index: 1720 recorded
# Calculations for index: 1740 recorded
# Calculations for index: 1760 recorded
# Calculations for index: 1780 recorded
# Calculations for index: 1800 recorded
# Calculations for index: 1820 recorded
# Calculations for index: 1840 recorded
# Calculations for index: 1860 recorded
# Calculations for index: 1880 recorded
# Calculations for index: 1900 recorded
# Calculations for index: 1920 recorded
# Calculations for index: 1940 recorded
# Calculations for index: 1960 recorded
# Calculations for index: 1980 recorded
# Calculations for index: 2000 recorded
# Calculations for index: 2020 recorded
# Calculations for index: 2040 recorded
# Calculations for index: 2060 recorded
# Calculations for index: 2080 recorded
# Calculations for index: 2100 recorded
# Calculations for index: 2120 recorded
# Calculations for index: 2140 recorded
# Calculations for index: 2160 recorded
# Calculations for index: 2180 recorded
# Calculations for index: 2200 recorded
# Calculations for index: 2220 recorded
# Calculations for index: 2240 recorded
# Calculations for index: 2260 recorded
# Calculations for index: 2280 recorded
# Calculations for index: 2300 recorded
# Calculations for index: 2320 recorded
# Calculations for index: 2340 recorded
# Calculations for index: 2360 recorded
# Calculations for index: 2380 recorded
# Calculations for index: 2400 recorded
# Calculations for index: 2420 recorded
# Calculations for index: 2440 recorded
# Calculations for index: 2460 recorded
# Calculations for index: 2480 recorded
# Calculations for index: 2500 recorded
# Calculations for index: 2520 recorded
# Calculations for index: 2540 recorded
# Calculations for index: 2560 recorded
# Calculations for index: 2580 recorded
# Calculations for index: 2600 recorded
# Calculations for index: 2620 recorded
# Calculations for index: 2640 recorded
# Calculations for index: 2660 recorded
# Calculations for index: 2680 recorded
# Calculations for index: 2700 recorded
# Calculations for index: 2720 recorded
# Calculations for index: 2740 recorded
# Calculations for index: 2760 recorded
# Calculations for index: 2780 recorded
# Calculations for index: 2800 recorded
# Calculations for index: 2820 recorded
# Calculations for index: 2840 recorded
# Calculations for index: 2860 recorded
# Calculations for index: 2880 recorded
# Calculations for index: 2900 recorded
# Calculations for index: 2920 recorded
# Calculations for index: 2940 recorded
# Calculations for index: 2960 recorded
# Calculations for index: 2980 recorded
# Calculations for index: 3000 recorded
# Calculations for index: 3020 recorded
# Calculations for index: 3040 recorded
# Calculations for index: 3060 recorded
# Calculations for index: 3080 recorded
# Calculations for index: 3100 recorded
# Calculations for index: 3120 recorded
# Calculations for index: 3140 recorded
# Calculations for index: 3160 recorded
# Calculations for index: 3180 recorded
# Calculations for index: 3200 recorded
# Calculations for index: 3220 recorded
# Calculations for index: 3240 recorded
# Calculations for index: 3260 recorded
# Calculations for index: 3280 recorded
# Calculations for index: 3300 recorded
# Calculations for index: 3320 recorded
# Calculations for index: 3340 recorded
# Calculations for index: 3360 recorded
# Calculations for index: 3380 recorded
# Calculations for index: 3400 recorded
# Calculations for index: 3420 recorded
# Calculations for index: 3440 recorded
# Calculations for index: 3460 recorded
# Calculations for index: 3480 recorded
# Calculations for index: 3500 recorded
# Calculations for index: 3520 recorded
# Calculations for index: 3540 recorded
# Calculations for index: 3560 recorded
# Calculations for index: 3580 recorded
# Calculations for index: 3600 recorded
# Calculations for index: 3620 recorded
# Calculations for index: 3640 recorded
# Calculations for index: 3660 recorded
# Calculations for index: 3680 recorded
# Calculations for index: 3700 recorded
# Calculations for index: 3720 recorded
# Calculations for index: 3740 recorded
# Calculations for index: 3760 recorded
# Calculations for index: 3780 recorded
# Calculations for index: 3800 recorded
# Calculations for index: 3820 recorded
# Calculations for index: 3840 recorded
# Calculations for index: 3860 recorded
# Calculations for index: 3880 recorded
# Calculations for index: 3900 recorded
# Calculations for index: 3920 recorded
# Calculations for index: 3940 recorded
# Calculations for index: 3960 recorded
# Calculations for index: 3980 recorded
# Calculations for index: 4000 recorded
# Calculations for index: 4020 recorded
# Calculations for index: 4040 recorded
# Calculations for index: 4060 recorded
# Calculations for index: 4080 recorded
# Calculations for index: 4100 recorded
# Calculations for index: 4120 recorded
# Calculations for index: 4140 recorded
# Calculations for index: 4160 recorded
# Calculations for index: 4180 recorded
# Calculations for index: 4200 recorded
# Calculations for index: 4220 recorded
# Calculations for index: 4240 recorded
# Calculations for index: 4260 recorded
# Calculations for index: 4280 recorded
# Calculations for index: 4300 recorded
# Calculations for index: 4320 recorded
# Calculations for index: 4340 recorded
# Calculations for index: 4360 recorded
# Calculations for index: 4380 recorded
# Calculations for index: 4400 recorded
# Calculations for index: 4420 recorded
# Calculations for index: 4440 recorded
# Calculations for index: 4460 recorded
# Calculations for index: 4480 recorded
# Calculations for index: 4500 recorded
# Calculations for index: 4520 recorded
# Calculations for index: 4540 recorded
# Calculations for index: 4560 recorded
# Calculations for index: 4580 recorded
# Calculations for index: 4600 recorded
# Calculations for index: 4620 recorded
# Calculations for index: 4640 recorded
# Calculations for index: 4660 recorded
# Calculations for index: 4680 recorded
# Calculations for index: 4700 recorded
# Calculations for index: 4720 recorded
# Calculations for index: 4740 recorded
# Calculations for index: 4760 recorded
# Calculations for index: 4780 recorded
# Calculations for index: 4800 recorded
# Calculations for index: 4820 recorded
# Calculations for index: 4840 recorded
# Calculations for index: 4860 recorded
# Calculations for index: 4880 recorded
# Calculations for index: 4900 recorded
# Calculations for index: 4920 recorded
# Calculations for index: 4940 recorded
# Calculations for index: 4960 recorded
# Calculations for index: 4980 recorded
# Calculations for index: 5000 recorded
# Calculations for index: 5020 recorded
# Calculations for index: 5040 recorded
# Calculations for index: 5060 recorded
# Calculations for index: 5080 recorded
# Calculations for index: 5100 recorded
# Calculations for index: 5120 recorded
# Calculations for index: 5140 recorded
# Calculations for index: 5160 recorded
# Calculations for index: 5180 recorded
# Calculations for index: 5200 recorded
# Calculations for index: 5220 recorded
# Calculations for index: 5240 recorded
# Calculations for index: 5260 recorded
# Calculations for index: 5280 recorded
# Calculations for index: 5300 recorded
# Calculations for index: 5320 recorded
# Calculations for index: 5340 recorded
# Calculations for index: 5360 recorded
# Calculations for index: 5380 recorded
# Calculations for index: 5400 recorded
# Calculations for index: 5420 recorded
# Calculations for index: 5440 recorded
# Calculations for index: 5460 recorded
# Calculations for index: 5480 recorded
# Calculations for index: 5500 recorded
# Calculations for index: 5520 recorded
# Calculations for index: 5540 recorded
# Calculations for index: 5560 recorded
# Calculations for index: 5580 recorded
# Calculations for index: 5600 recorded
# Calculations for index: 5620 recorded
# Calculations for index: 5640 recorded
# Calculations for index: 5660 recorded
# Calculations for index: 5680 recorded
# Calculations for index: 5700 recorded
# Calculations for index: 5720 recorded
# Calculations for index: 5740 recorded
# Calculations for index: 5760 recorded
# Calculations for index: 5780 recorded
# Calculations for index: 5800 recorded
# Calculations for index: 5820 recorded
# Calculations for index: 5840 recorded
# Calculations for index: 5860 recorded
# Calculations for index: 5880 recorded
# Calculations for index: 5900 recorded
# Calculations for index: 5920 recorded
# Calculations for index: 5940 recorded
# Calculations for index: 5960 recorded
# Calculations for index: 5980 recorded
# Calculations for index: 6000 recorded
# Calculations for index: 6020 recorded
# Calculations for index: 6040 recorded
# Calculations for index: 6060 recorded
# Calculations for index: 6080 recorded
# Calculations for index: 6100 recorded
# Calculations for index: 6120 recorded
# Calculations for index: 6140 recorded
# Calculations for index: 6160 recorded
# Calculations for index: 6180 recorded
# Calculations for index: 6200 recorded
# Calculations for index: 6220 recorded
# Calculations for index: 6240 recorded
# Calculations for index: 6260 recorded
# Calculations for index: 6280 recorded
# Calculations for index: 6300 recorded
# Calculations for index: 6320 recorded
# Calculations for index: 6340 recorded
# Calculations for index: 6360 recorded
# Calculations for index: 6380 recorded
# Calculations for index: 6400 recorded
# Calculations for index: 6420 recorded
# Calculations for index: 6440 recorded
# Calculations for index: 6460 recorded
# Calculations for index: 6480 recorded
# Calculations for index: 6500 recorded
# Calculations for index: 6520 recorded
# Calculations for index: 6540 recorded
# Calculations for index: 6560 recorded
# Calculations for index: 6580 recorded
# Calculations for index: 6600 recorded
# Calculations for index: 6620 recorded
# Calculations for index: 6640 recorded
# Calculations for index: 6660 recorded
# Calculations for index: 6680 recorded
# Calculations for index: 6700 recorded
# Calculations for index: 6720 recorded
# Calculations for index: 6740 recorded
# Calculations for index: 6760 recorded
# Calculations for index: 6780 recorded
# Calculations for index: 6800 recorded
# Calculations for index: 6820 recorded
# Calculations for index: 6840 recorded
# Calculations for index: 6860 recorded
# Calculations for index: 6880 recorded
# Calculations for index: 6900 recorded
# Calculations for index: 6920 recorded
# Calculations for index: 6940 recorded
# Calculations for index: 6960 recorded
# Calculations for index: 6980 recorded
# Calculations for index: 7000 recorded
# Calculations for index: 7020 recorded
# Calculations for index: 7040 recorded
# Calculations for index: 7060 recorded
# Calculations for index: 7080 recorded
# Calculations for index: 7100 recorded
# Calculations for index: 7120 recorded
# Calculations for index: 7140 recorded
# Calculations for index: 7160 recorded
# Calculations for index: 7180 recorded
# Calculations for index: 7200 recorded
# Calculations for index: 7220 recorded
# Calculations for index: 7240 recorded
# Calculations for index: 7260 recorded
# Calculations for index: 7280 recorded
# Calculations for index: 7300 recorded
# Calculations for index: 7320 recorded
# Calculations for index: 7340 recorded
# Calculations for index: 7360 recorded
# Calculations for index: 7380 recorded
# Calculations for index: 7400 recorded
# Calculations for index: 7420 recorded
# Calculations for index: 7440 recorded
# Calculations for index: 7460 recorded
# Calculations for index: 7480 recorded
# Calculations for index: 7500 recorded
# Calculations for index: 7520 recorded
# Calculations for index: 7540 recorded
# Calculations for index: 7560 recorded
# Calculations for index: 7580 recorded
# Calculations for index: 7600 recorded
# Calculations for index: 7620 recorded
# Calculations for index: 7640 recorded
# Calculations for index: 7660 recorded
# Calculations for index: 7680 recorded
# Calculations for index: 7700 recorded
# Calculations for index: 7720 recorded
# Calculations for index: 7740 recorded
# Calculations for index: 7760 recorded
# Calculations for index: 7780 recorded
# Calculations for index: 7800 recorded
# Calculations for index: 7820 recorded
# Calculations for index: 7840 recorded
# Calculations for index: 7860 recorded
# Calculations for index: 7880 recorded
# Calculations for index: 7900 recorded
# Calculations for index: 7920 recorded
# Calculations for index: 7940 recorded
# Calculations for index: 7960 recorded
# Calculations for index: 7980 recorded
# Calculations for index: 8000 recorded
# Calculations for index: 8020 recorded
# Calculations for index: 8040 recorded
# Calculations for index: 8060 recorded
# Calculations for index: 8080 recorded
# Calculations for index: 8100 recorded
# Calculations for index: 8120 recorded
# Calculations for index: 8140 recorded
# Calculations for index: 8160 recorded
# Calculations for index: 8180 recorded
# Calculations for index: 8200 recorded
# Calculations for index: 8220 recorded
# Calculations for index: 8240 recorded
# Calculations for index: 8260 recorded
# Calculations for index: 8280 recorded
# Calculations for index: 8300 recorded
# Calculations for index: 8320 recorded
# Calculations for index: 8340 recorded
# Calculations for index: 8360 recorded
# Calculations for index: 8380 recorded
# Calculations for index: 8400 recorded
# Calculations for index: 8420 recorded
# Calculations for index: 8440 recorded
# Calculations for index: 8460 recorded
# Calculations for index: 8480 recorded
# Calculations for index: 8500 recorded
# Calculations for index: 8520 recorded
# Calculations for index: 8540 recorded
# Calculations for index: 8560 recorded
# Calculations for index: 8580 recorded
# Calculations for index: 8600 recorded
# Calculations for index: 8620 recorded
# Calculations for index: 8640 recorded
# Calculations for index: 8660 recorded
# Calculations for index: 8680 recorded
# Calculations for index: 8700 recorded
# Calculations for index: 8720 recorded
# Calculations for index: 8740 recorded
# Calculations for index: 8760 recorded
# Calculations for index: 8780 recorded
# Calculations for index: 8800 recorded
# Calculations for index: 8820 recorded
# Calculations for index: 8840 recorded
# Calculations for index: 8860 recorded
# Calculations for index: 8880 recorded
# Calculations for index: 8900 recorded
# Calculations for index: 8920 recorded
# Calculations for index: 8940 recorded
# Calculations for index: 8960 recorded
# Calculations for index: 8980 recorded
# Calculations for index: 9000 recorded
# Calculations for index: 9020 recorded
# Calculations for index: 9040 recorded
# Calculations for index: 9060 recorded
# Calculations for index: 9080 recorded
# Calculations for index: 9100 recorded
# Calculations for index: 9120 recorded
# Calculations for index: 9140 recorded
# Calculations for index: 9160 recorded
# Calculations for index: 9180 recorded
# Calculations for index: 9200 recorded
# Calculations for index: 9220 recorded
# Calculations for index: 9240 recorded
# Calculations for index: 9260 recorded
# Calculations for index: 9280 recorded
# Calculations for index: 9300 recorded
# Calculations for index: 9320 recorded
# Calculations for index: 9340 recorded
# Calculations for index: 9360 recorded
# Calculations for index: 9380 recorded
# Calculations for index: 9400 recorded
# Calculations for index: 9420 recorded
# Calculations for index: 9440 recorded
# Calculations for index: 9460 recorded
# Calculations for index: 9480 recorded
# Calculations for index: 9500 recorded
# Calculations for index: 9520 recorded
# Calculations for index: 9540 recorded
# Calculations for index: 9560 recorded
# Calculations for index: 9580 recorded
# Calculations for index: 9600 recorded
# Calculations for index: 9620 recorded
# Calculations for index: 9640 recorded
# Calculations for index: 9660 recorded
# Calculations for index: 9680 recorded
# Calculations for index: 9700 recorded
# Calculations for index: 9720 recorded
# Calculations for index: 9740 recorded
# Calculations for index: 9760 recorded
# Calculations for index: 9780 recorded
# Calculations for index: 9800 recorded
# Calculations for index: 9820 recorded
# Calculations for index: 9840 recorded
# Calculations for index: 9860 recorded
# Calculations for index: 9880 recorded
# Calculations for index: 9900 recorded
# Calculations for index: 9920 recorded
# Calculations for index: 9940 recorded
# Calculations for index: 9960 recorded
# Calculations for index: 9980 recorded
# Calculations for index: 10000 recorded
# Calculations for index: 10020 recorded
# Calculations for index: 10040 recorded
# Calculations for index: 10060 recorded
# Calculations for index: 10080 recorded
# Calculations for index: 10100 recorded
# Calculations for index: 10120 recorded
# Calculations for index: 10140 recorded
# Calculations for index: 10160 recorded
# Calculations for index: 10180 recorded
# Calculations for index: 10200 recorded
# Calculations for index: 10220 recorded
# Calculations for index: 10240 recorded
# Calculations for index: 10260 recorded
# Calculations for index: 10280 recorded
# Calculations for index: 10300 recorded
# Calculations for index: 10320 recorded
# Calculations for index: 10340 recorded
# Calculations for index: 10360 recorded
# Calculations for index: 10380 recorded
# Calculations for index: 10400 recorded
# Calculations for index: 10420 recorded
# Calculations for index: 10440 recorded
# Calculations for index: 10460 recorded
# Calculations for index: 10480 recorded
# Calculations for index: 10500 recorded
# Calculations for index: 10520 recorded
# Calculations for index: 10540 recorded
# Calculations for index: 10560 recorded
# Calculations for index: 10580 recorded
# Calculations for index: 10600 recorded
# Calculations for index: 10620 recorded
# Calculations for index: 10640 recorded
# Calculations for index: 10660 recorded
# Calculations for index: 10680 recorded
# Calculations for index: 10700 recorded
# Calculations for index: 10720 recorded
# Calculations for index: 10740 recorded
# Calculations for index: 10760 recorded
# Calculations for index: 10780 recorded
# Calculations for index: 10800 recorded
# Calculations for index: 10820 recorded
# Calculations for index: 10840 recorded
# Calculations for index: 10860 recorded
# Calculations for index: 10880 recorded
# Calculations for index: 10900 recorded
# Calculations for index: 10920 recorded
# Calculations for index: 10940 recorded
# Calculations for index: 10960 recorded
# Calculations for index: 10980 recorded
# Calculations for index: 11000 recorded
# Calculations for index: 11020 recorded
# Calculations for index: 11040 recorded
# Calculations for index: 11060 recorded
# Calculations for index: 11080 recorded
# Calculations for index: 11100 recorded
# Calculations for index: 11120 recorded
# Calculations for index: 11140 recorded
# Calculations for index: 11160 recorded
# Calculations for index: 11180 recorded
# Calculations for index: 11200 recorded
# Calculations for index: 11220 recorded
# Calculations for index: 11240 recorded
# Calculations for index: 11260 recorded
# Calculations for index: 11280 recorded
# Calculations for index: 11300 recorded
# Calculations for index: 11320 recorded
# Calculations for index: 11340 recorded
# Calculations for index: 11360 recorded
# Calculations for index: 11380 recorded
# Calculations for index: 11400 recorded
# Calculations for index: 11420 recorded
# Calculations for index: 11440 recorded
# Calculations for index: 11460 recorded
# Calculations for index: 11480 recorded
# Calculations for index: 11500 recorded
# Calculations for index: 11520 recorded
# Calculations for index: 11540 recorded
# Calculations for index: 11560 recorded
# Calculations for index: 11580 recorded
# Calculations for index: 11600 recorded
# Calculations for index: 11620 recorded
# Calculations for index: 11640 recorded
# Calculations for index: 11660 recorded
# Calculations for index: 11680 recorded
# Calculations for index: 11700 recorded
# Calculations for index: 11720 recorded
# Calculations for index: 11740 recorded
# Calculations for index: 11760 recorded
# Calculations for index: 11780 recorded
# Calculations for index: 11800 recorded
# Calculations for index: 11820 recorded
# Calculations for index: 11840 recorded
# Calculations for index: 11860 recorded
# Calculations for index: 11880 recorded
# Calculations for index: 11900 recorded
# Calculations for index: 11920 recorded
# Calculations for index: 11940 recorded
# Calculations for index: 11960 recorded
# Calculations for index: 11980 recorded
# Calculations for index: 12000 recorded
# Calculations for index: 12020 recorded
# Calculations for index: 12040 recorded
# Calculations for index: 12060 recorded
# Calculations for index: 12080 recorded
# Calculations for index: 12100 recorded
# Calculations for index: 12120 recorded
# Calculations for index: 12140 recorded
# Calculations for index: 12160 recorded
# Calculations for index: 12180 recorded
# Calculations for index: 12200 recorded
# Calculations for index: 12220 recorded
# Calculations for index: 12240 recorded
# Calculations for index: 12260 recorded
# Calculations for index: 12280 recorded
# Calculations for index: 12300 recorded
# Calculations for index: 12320 recorded
# Calculations for index: 12340 recorded
# Calculations for index: 12360 recorded
# Calculations for index: 12380 recorded
# Calculations for index: 12400 recorded
# Calculations for index: 12420 recorded
# Calculations for index: 12440 recorded
# Calculations for index: 12460 recorded
# Calculations for index: 12480 recorded
# Calculations for index: 12500 recorded
# Calculations for index: 12520 recorded
# Calculations for index: 12540 recorded
# Calculations for index: 12560 recorded
# Calculations for index: 12580 recorded
# Calculations for index: 12600 recorded
# Calculations for index: 12620 recorded
# Calculations for index: 12640 recorded
# Calculations for index: 12660 recorded
# Calculations for index: 12680 recorded
# Calculations for index: 12700 recorded
# Calculations for index: 12720 recorded
# Calculations for index: 12740 recorded
# Calculations for index: 12760 recorded
# Calculations for index: 12780 recorded
# Calculations for index: 12800 recorded
# Calculations for index: 12820 recorded
# Calculations for index: 12840 recorded
# Calculations for index: 12860 recorded
# Calculations for index: 12880 recorded
# Calculations for index: 12900 recorded
# Calculations for index: 12920 recorded
# Calculations for index: 12940 recorded
# Calculations for index: 12960 recorded
# Calculations for index: 12980 recorded
# Calculations for index: 13000 recorded
# Calculations for index: 13020 recorded
# Calculations for index: 13040 recorded
# Calculations for index: 13060 recorded
# Calculations for index: 13080 recorded
# Calculations for index: 13100 recorded
# Calculations for index: 13120 recorded
# Calculations for index: 13140 recorded
# Calculations for index: 13160 recorded
# Calculations for index: 13180 recorded
# Calculations for index: 13200 recorded
# Calculations for index: 13220 recorded
# Calculations for index: 13240 recorded
# Calculations for index: 13260 recorded
# Calculations for index: 13280 recorded
# Calculations for index: 13300 recorded
# Calculations for index: 13320 recorded
# Calculations for index: 13340 recorded
# Calculations for index: 13360 recorded
# Calculations for index: 13380 recorded
# Calculations for index: 13400 recorded
# Calculations for index: 13420 recorded
# Calculations for index: 13440 recorded
# Calculations for index: 13460 recorded
# Calculations for index: 13480 recorded
# Calculations for index: 13500 recorded
# Calculations for index: 13520 recorded
# Calculations for index: 13540 recorded
# Calculations for index: 13560 recorded
# Calculations for index: 13580 recorded
# Calculations for index: 13600 recorded
# Calculations for index: 13620 recorded
# Calculations for index: 13640 recorded
# Calculations for index: 13660 recorded
# Calculations for index: 13680 recorded
# Calculations for index: 13700 recorded
# Calculations for index: 13720 recorded
# Calculations for index: 13740 recorded
# Calculations for index: 13760 recorded
# Calculations for index: 13780 recorded
# Calculations for index: 13800 recorded
# Calculations for index: 13820 recorded
# Calculations for index: 13840 recorded
# Calculations for index: 13860 recorded
# Calculations for index: 13880 recorded
# Calculations for index: 13900 recorded
# Calculations for index: 13920 recorded
# Calculations for index: 13940 recorded
# Calculations for index: 13960 recorded
# Calculations for index: 13980 recorded
# Calculations for index: 14000 recorded
# Calculations for index: 14020 recorded
# Calculations for index: 14040 recorded
# Calculations for index: 14060 recorded
# Calculations for index: 14080 recorded
# Calculations for index: 14100 recorded
# Calculations for index: 14120 recorded
# Calculations for index: 14140 recorded
# Calculations for index: 14160 recorded
# Calculations for index: 14180 recorded
# Calculations for index: 14200 recorded
# Calculations for index: 14220 recorded
# Calculations for index: 14240 recorded
# Calculations for index: 14260 recorded
# Calculations for index: 14280 recorded
# Calculations for index: 14300 recorded
# Calculations for index: 14320 recorded
# Calculations for index: 14340 recorded
# Calculations for index: 14360 recorded
# Calculations for index: 14380 recorded
# Calculations for index: 14400 recorded
# Calculations for index: 14420 recorded
# Calculations for index: 14440 recorded
# Calculations for index: 14460 recorded
# Calculations for index: 14480 recorded
# Calculations for index: 14500 recorded
# Calculations for index: 14520 recorded
# Calculations for index: 14540 recorded
# Calculations for index: 14560 recorded
# Calculations for index: 14580 recorded
# Calculations for index: 14600 recorded
# Calculations for index: 14620 recorded
# Calculations for index: 14640 recorded
# Calculations for index: 14660 recorded
# Calculations for index: 14680 recorded
# Calculations for index: 14700 recorded
# Calculations for index: 14720 recorded
# Calculations for index: 14740 recorded
# Calculations for index: 14760 recorded
# Calculations for index: 14780 recorded
# Calculations for index: 14800 recorded
# Calculations for index: 14820 recorded
# Calculations for index: 14840 recorded
# Calculations for index: 14860 recorded
# Calculations for index: 14880 recorded
# Calculations for index: 14900 recorded
# Calculations for index: 14920 recorded
# Calculations for index: 14940 recorded
# Calculations for index: 14960 recorded
# Calculations for index: 14980 recorded
# Calculations for index: 15000 recorded
# Calculations for index: 15020 recorded
# Calculations for index: 15040 recorded
# Calculations for index: 15060 recorded
# Calculations for index: 15080 recorded
# Calculations for index: 15100 recorded
# Calculations for index: 15120 recorded
# Calculations for index: 15140 recorded
# Calculations for index: 15160 recorded
# Calculations for index: 15180 recorded
# Calculations for index: 15200 recorded
# Calculations for index: 15220 recorded
# Calculations for index: 15240 recorded
# Calculations for index: 15260 recorded
# Calculations for index: 15280 recorded
# Calculations for index: 15300 recorded
# Calculations for index: 15320 recorded
# Calculations for index: 15340 recorded
# Calculations for index: 15360 recorded
# Calculations for index: 15380 recorded
# Calculations for index: 15400 recorded
# Calculations for index: 15420 recorded
# Calculations for index: 15440 recorded
# Calculations for index: 15460 recorded
# Calculations for index: 15480 recorded
# Calculations for index: 15500 recorded
# Calculations for index: 15520 recorded
# Calculations for index: 15540 recorded
# Calculations for index: 15560 recorded
# Calculations for index: 15580 recorded
# Calculations for index: 15600 recorded
# Calculations for index: 15620 recorded
# Calculations for index: 15640 recorded
# Calculations for index: 15660 recorded
# Calculations for index: 15680 recorded
# Calculations for index: 15700 recorded
# Calculations for index: 15720 recorded
# Calculations for index: 15740 recorded
# Calculations for index: 15760 recorded
# Calculations for index: 15780 recorded
# Calculations for index: 15800 recorded
# Calculations for index: 15820 recorded
# Calculations for index: 15840 recorded
# Calculations for index: 15860 recorded
# Calculations for index: 15880 recorded
# Calculations for index: 15900 recorded
# Calculations for index: 15920 recorded
# Calculations for index: 15940 recorded
# Calculations for index: 15960 recorded
# Calculations for index: 15980 recorded
# Calculations for index: 16000 recorded
# Calculations for index: 16020 recorded
# Calculations for index: 16040 recorded
# Calculations for index: 16060 recorded
# Calculations for index: 16080 recorded
# Calculations for index: 16100 recorded
# Calculations for index: 16120 recorded
# Calculations for index: 16140 recorded
# Calculations for index: 16160 recorded
# Calculations for index: 16180 recorded
# Calculations for index: 16200 recorded
# Calculations for index: 16220 recorded
# Calculations for index: 16240 recorded
# Calculations for index: 16260 recorded
# Calculations for index: 16280 recorded
# Calculations for index: 16300 recorded
# Calculations for index: 16320 recorded
# Calculations for index: 16340 recorded
# Calculations for index: 16360 recorded
# Calculations for index: 16380 recorded
# Calculations for index: 16400 recorded
# Calculations for index: 16420 recorded
# Calculations for index: 16440 recorded
# Calculations for index: 16460 recorded
# Calculations for index: 16480 recorded
# Calculations for index: 16500 recorded
# Calculations for index: 16520 recorded
# Calculations for index: 16540 recorded
# Calculations for index: 16560 recorded
# Calculations for index: 16580 recorded
# Calculations for index: 16600 recorded
# Calculations for index: 16620 recorded
# Calculations for index: 16640 recorded
# Calculations for index: 16660 recorded
# Calculations for index: 16680 recorded
# Calculations for index: 16700 recorded
# Calculations for index: 16720 recorded
# Calculations for index: 16740 recorded
# Calculations for index: 16760 recorded
# Calculations for index: 16780 recorded
# Calculations for index: 16800 recorded
# Calculations for index: 16820 recorded
# Calculations for index: 16840 recorded
# Calculations for index: 16860 recorded
# Calculations for index: 16880 recorded
# Calculations for index: 16900 recorded
# Calculations for index: 16920 recorded
# Calculations for index: 16940 recorded
# Calculations for index: 16960 recorded
# Calculations for index: 16980 recorded
# Calculations for index: 17000 recorded
# Calculations for index: 17020 recorded
# Calculations for index: 17040 recorded
# Calculations for index: 17060 recorded
# Calculations for index: 17080 recorded
# Calculations for index: 17100 recorded
# Calculations for index: 17120 recorded
# Calculations for index: 17140 recorded
# Calculations for index: 17160 recorded
# Calculations for index: 17180 recorded
# Calculations for index: 17200 recorded
# Calculations for index: 17220 recorded
# Calculations for index: 17240 recorded
# Calculations for index: 17260 recorded
# Calculations for index: 17280 recorded
# Calculations for index: 17300 recorded
# Calculations for index: 17320 recorded
# Calculations for index: 17340 recorded
# Calculations for index: 17360 recorded
# Calculations for index: 17380 recorded
# Calculations for index: 17400 recorded
# Calculations for index: 17420 recorded
# Calculations for index: 17440 recorded
# Calculations for index: 17460 recorded
# Calculations for index: 17480 recorded
# Calculations for index: 17500 recorded
# Calculations for index: 17520 recorded
# Calculations for index: 17540 recorded
# Calculations for index: 17560 recorded
# Calculations for index: 17580 recorded
# Calculations for index: 17600 recorded
# Calculations for index: 17620 recorded
# Calculations for index: 17640 recorded
# Calculations for index: 17660 recorded
# Calculations for index: 17680 recorded
# Calculations for index: 17700 recorded
# Calculations for index: 17720 recorded
# Calculations for index: 17740 recorded
# Calculations for index: 17760 recorded
# Calculations for index: 17780 recorded
# Calculations for index: 17800 recorded
# Calculations for index: 17820 recorded
# Calculations for index: 17840 recorded
# Calculations for index: 17860 recorded
# Calculations for index: 17880 recorded
# Calculations for index: 17900 recorded
# Calculations for index: 17920 recorded
# Calculations for index: 17940 recorded
# Calculations for index: 17960 recorded
# Calculations for index: 17980 recorded
# Calculations for index: 18000 recorded
# Calculations for index: 18020 recorded
# Calculations for index: 18040 recorded
# Calculations for index: 18060 recorded
# Calculations for index: 18080 recorded
# Calculations for index: 18100 recorded
# Calculations for index: 18120 recorded
# Calculations for index: 18140 recorded
# Calculations for index: 18160 recorded
# Calculations for index: 18180 recorded
# Calculations for index: 18200 recorded
# Calculations for index: 18220 recorded
# Calculations for index: 18240 recorded
# Calculations for index: 18260 recorded
# Calculations for index: 18280 recorded
# Calculations for index: 18300 recorded
# Calculations for index: 18320 recorded
# Calculations for index: 18340 recorded
# Calculations for index: 18360 recorded
# Calculations for index: 18380 recorded
# Calculations for index: 18400 recorded
# Calculations for index: 18420 recorded
# Calculations for index: 18440 recorded
# Calculations for index: 18460 recorded
# Calculations for index: 18480 recorded
# Calculations for index: 18500 recorded
# Calculations for index: 18520 recorded
# Calculations for index: 18540 recorded
# Calculations for index: 18560 recorded
# Calculations for index: 18580 recorded
# Calculations for index: 18600 recorded
# Calculations for index: 18620 recorded
# Calculations for index: 18640 recorded
# Calculations for index: 18660 recorded
# Calculations for index: 18680 recorded
# Calculations for index: 18700 recorded
# Calculations for index: 18720 recorded
# Calculations for index: 18740 recorded
# Calculations for index: 18760 recorded
# Calculations for index: 18780 recorded
# Calculations for index: 18800 recorded
# Calculations for index: 18820 recorded
# Calculations for index: 18840 recorded
# Calculations for index: 18860 recorded
# Calculations for index: 18880 recorded
# Calculations for index: 18900 recorded
# Calculations for index: 18920 recorded
# Calculations for index: 18940 recorded
# Calculations for index: 18960 recorded
# Calculations for index: 18980 recorded
# Calculations for index: 19000 recorded
# Calculations for index: 19020 recorded
# Calculations for index: 19040 recorded
# Calculations for index: 19060 recorded
# Calculations for index: 19080 recorded
# Calculations for index: 19100 recorded
# Calculations for index: 19120 recorded
# Calculations for index: 19140 recorded
# Calculations for index: 19160 recorded
# Calculations for index: 19180 recorded
# Calculations for index: 19200 recorded
# Calculations for index: 19220 recorded
# Calculations for index: 19240 recorded
# Calculations for index: 19260 recorded
# Calculations for index: 19280 recorded
# Calculations for index: 19300 recorded
# Calculations for index: 19320 recorded
# Calculations for index: 19340 recorded
# Calculations for index: 19360 recorded
# Calculations for index: 19380 recorded
# Calculations for index: 19400 recorded
# Calculations for index: 19420 recorded
# Calculations for index: 19440 recorded
# Calculations for index: 19460 recorded
# Calculations for index: 19480 recorded
# Calculations for index: 19500 recorded
# Calculations for index: 19520 recorded
# Calculations for index: 19540 recorded
# Calculations for index: 19560 recorded
# Calculations for index: 19580 recorded
# Calculations for index: 19600 recorded
# Calculations for index: 19620 recorded
# Calculations for index: 19640 recorded
# Calculations for index: 19660 recorded
# Calculations for index: 19680 recorded
# Calculations for index: 19700 recorded
# Calculations for index: 19720 recorded
# Calculations for index: 19740 recorded
# Calculations for index: 19760 recorded
# Calculations for index: 19780 recorded
# Calculations for index: 19800 recorded
# Calculations for index: 19820 recorded
# Calculations for index: 19840 recorded
# Calculations for index: 19860 recorded
# Calculations for index: 19880 recorded
# Calculations for index: 19900 recorded
# Calculations for index: 19920 recorded
# Calculations for index: 19940 recorded
# Calculations for index: 19960 recorded
# Calculations for index: 19980 recorded
# Calculations for index: 20000 recorded
# Calculations for index: 20020 recorded
# Calculations for index: 20040 recorded
# Calculations for index: 20060 recorded
# Calculations for index: 20080 recorded
# Calculations for index: 20100 recorded
# Calculations for index: 20120 recorded
# Calculations for index: 20140 recorded
# Calculations for index: 20160 recorded
# Calculations for index: 20180 recorded
# Calculations for index: 20200 recorded
# Calculations for index: 20220 recorded
# Calculations for index: 20240 recorded
# Calculations for index: 20260 recorded
# Calculations for index: 20280 recorded
# Calculations for index: 20300 recorded
# Calculations for index: 20320 recorded
# Calculations for index: 20340 recorded
# Calculations for index: 20360 recorded
# Calculations for index: 20380 recorded
# Calculations for index: 20400 recorded
# Calculations for index: 20420 recorded
# Calculations for index: 20440 recorded
# Calculations for index: 20460 recorded
# Calculations for index: 20480 recorded
# Calculations for index: 20500 recorded
# Calculations for index: 20520 recorded
# Calculations for index: 20540 recorded
# Calculations for index: 20560 recorded
# Calculations for index: 20580 recorded
# Calculations for index: 20600 recorded
# Calculations for index: 20620 recorded
# Calculations for index: 20640 recorded
# Calculations for index: 20660 recorded
# Calculations for index: 20680 recorded
# Calculations for index: 20700 recorded
# Calculations for index: 20720 recorded
# Calculations for index: 20740 recorded
# Calculations for index: 20760 recorded
# Calculations for index: 20780 recorded
# Calculations for index: 20800 recorded
# Calculations for index: 20820 recorded
# Calculations for index: 20840 recorded
# Calculations for index: 20860 recorded
# Calculations for index: 20880 recorded
# Calculations for index: 20900 recorded
# Calculations for index: 20920 recorded
# Calculations for index: 20940 recorded
# Calculations for index: 20960 recorded
# Calculations for index: 20980 recorded
# Calculations for index: 21000 recorded
# Calculations for index: 21020 recorded
# Calculations for index: 21040 recorded
# Calculations for index: 21060 recorded
# Calculations for index: 21080 recorded
# Calculations for index: 21100 recorded
# Calculations for index: 21120 recorded
# Calculations for index: 21140 recorded
# Calculations for index: 21160 recorded
# Calculations for index: 21180 recorded
# Calculations for index: 21200 recorded
# Calculations for index: 21220 recorded
# Calculations for index: 21240 recorded
# Calculations for index: 21260 recorded
# Calculations for index: 21280 recorded
# Calculations for index: 21300 recorded
# Calculations for index: 21320 recorded
# Calculations for index: 21340 recorded
# Calculations for index: 21360 recorded
# Calculations for index: 21380 recorded
# Calculations for index: 21400 recorded
# Calculations for index: 21420 recorded
# Calculations for index: 21440 recorded
# Calculations for index: 21460 recorded
# Calculations for index: 21480 recorded
# Calculations for index: 21500 recorded
# Calculations for index: 21520 recorded
# Calculations for index: 21540 recorded
# Calculations for index: 21560 recorded
# Calculations for index: 21580 recorded
# Calculations for index: 21600 recorded
# Calculations for index: 21620 recorded
# Calculations for index: 21640 recorded
# Calculations for index: 21660 recorded
# Calculations for index: 21680 recorded
# Calculations for index: 21700 recorded
# Calculations for index: 21720 recorded
# Calculations for index: 21740 recorded
# Calculations for index: 21760 recorded
# Calculations for index: 21780 recorded
# Calculations for index: 21800 recorded
# Calculations for index: 21820 recorded
# Calculations for index: 21840 recorded
# Calculations for index: 21860 recorded
# Calculations for index: 21880 recorded
# Calculations for index: 21900 recorded
# Calculations for index: 21920 recorded
# Calculations for index: 21940 recorded
# Calculations for index: 21960 recorded
# Calculations for index: 21980 recorded
# Calculations for index: 22000 recorded
# Calculations for index: 22020 recorded
# Calculations for index: 22040 recorded
# Calculations for index: 22060 recorded
# Calculations for index: 22080 recorded
# Calculations for index: 22100 recorded
# Calculations for index: 22120 recorded
# Calculations for index: 22140 recorded
# Calculations for index: 22160 recorded
# Calculations for index: 22180 recorded
# Calculations for index: 22200 recorded
# Calculations for index: 22220 recorded
# Calculations for index: 22240 recorded
# Calculations for index: 22260 recorded
# Calculations for index: 22280 recorded
# Calculations for index: 22300 recorded
# Calculations for index: 22320 recorded
# Calculations for index: 22340 recorded
# Calculations for index: 22360 recorded
# Calculations for index: 22380 recorded
# Calculations for index: 22400 recorded
# Calculations for index: 22420 recorded
# Calculations for index: 22440 recorded
# Calculations for index: 22460 recorded
# Calculations for index: 22480 recorded
# Calculations for index: 22500 recorded
# Calculations for index: 22520 recorded
# Calculations for index: 22540 recorded
# Calculations for index: 22560 recorded
# Calculations for index: 22580 recorded
# Calculations for index: 22600 recorded
# Calculations for index: 22620 recorded
# Calculations for index: 22640 recorded
# Calculations for index: 22660 recorded
# Calculations for index: 22680 recorded
# Calculations for index: 22700 recorded
# Calculations for index: 22720 recorded
# Calculations for index: 22740 recorded
# Calculations for index: 22760 recorded
# Calculations for index: 22780 recorded
# Calculations for index: 22800 recorded
# Calculations for index: 22820 recorded
# Calculations for index: 22840 recorded
# Calculations for index: 22860 recorded
# Calculations for index: 22880 recorded
# Calculations for index: 22900 recorded
# Calculations for index: 22920 recorded
# Calculations for index: 22940 recorded
# Calculations for index: 22960 recorded
# Calculations for index: 22980 recorded
# Calculations for index: 23000 recorded
# Calculations for index: 23020 recorded
# Calculations for index: 23040 recorded
# Calculations for index: 23060 recorded
# Calculations for index: 23080 recorded
# Calculations for index: 23100 recorded
# Calculations for index: 23120 recorded
# Calculations for index: 23140 recorded
# Calculations for index: 23160 recorded
# Calculations for index: 23180 recorded
# Calculations for index: 23200 recorded
# Calculations for index: 23220 recorded
# Calculations for index: 23240 recorded
# Calculations for index: 23260 recorded
# Calculations for index: 23280 recorded
# Calculations for index: 23300 recorded
# Calculations for index: 23320 recorded
# Calculations for index: 23340 recorded
# Calculations for index: 23360 recorded
# Calculations for index: 23380 recorded
# Calculations for index: 23400 recorded
# Calculations for index: 23420 recorded
# Calculations for index: 23440 recorded
# Calculations for index: 23460 recorded
# Calculations for index: 23480 recorded
# Calculations for index: 23500 recorded
# Calculations for index: 23520 recorded
# Calculations for index: 23540 recorded
# Calculations for index: 23560 recorded
# Calculations for index: 23580 recorded
# Calculations for index: 23600 recorded
# Calculations for index: 23620 recorded
# Calculations for index: 23640 recorded
# Calculations for index: 23660 recorded
# Calculations for index: 23680 recorded
# Calculations for index: 23700 recorded
# Calculations for index: 23720 recorded
# Calculations for index: 23740 recorded
# Calculations for index: 23760 recorded
# Calculations for index: 23780 recorded
# Calculations for index: 23800 recorded
# Calculations for index: 23820 recorded
# Calculations for index: 23840 recorded
# Calculations for index: 23860 recorded
# Calculations for index: 23880 recorded
# Calculations for index: 23900 recorded
# Calculations for index: 23920 recorded
# Calculations for index: 23940 recorded
# Calculations for index: 23960 recorded
# Calculations for index: 23980 recorded
# Calculations for index: 24000 recorded
# Calculations for index: 24020 recorded
# Calculations for index: 24040 recorded
# Calculations for index: 24060 recorded
# Calculations for index: 24080 recorded
# Calculations for index: 24100 recorded
# Calculations for index: 24120 recorded
# Calculations for index: 24140 recorded
# Calculations for index: 24160 recorded
# Calculations for index: 24180 recorded
# Calculations for index: 24200 recorded
# Calculations for index: 24220 recorded
# Calculations for index: 24240 recorded
# Calculations for index: 24260 recorded
# Calculations for index: 24280 recorded
# Calculations for index: 24300 recorded
# Calculations for index: 24320 recorded
# Calculations for index: 24340 recorded
# Calculations for index: 24360 recorded
# Calculations for index: 24380 recorded
# Calculations for index: 24400 recorded
# Calculations for index: 24420 recorded
# Calculations for index: 24440 recorded
# Calculations for index: 24460 recorded
# Calculations for index: 24480 recorded
# Calculations for index: 24500 recorded
# Calculations for index: 24520 recorded
# Calculations for index: 24540 recorded
# Calculations for index: 24560 recorded
# Calculations for index: 24580 recorded
# Calculations for index: 24600 recorded
# Calculations for index: 24620 recorded
# Calculations for index: 24640 recorded
# Calculations for index: 24660 recorded
# Calculations for index: 24680 recorded
# Calculations for index: 24700 recorded
# Calculations for index: 24720 recorded
# Calculations for index: 24740 recorded
# Calculations for index: 24760 recorded
# Calculations for index: 24780 recorded
# Calculations for index: 24800 recorded
# Calculations for index: 24820 recorded
# Calculations for index: 24840 recorded
# ...
# Calculations for index: 31820 recorded
# Calculations for index: 31840 recorded
# Calculations for index: 31860 recorded
# Calculations for index: 31880 recorded
# Calculations for index: 31900 recorded
# Calculations for index: 31920 recorded
# Calculations for index: 31940 recorded
# Calculations for index: 31960 recorded
# Calculations for index: 31980 recorded
# Calculations for index: 32000 recorded
# Calculations for index: 32020 recorded
# Calculations for index: 32040 recorded
# Calculations for index: 32060 recorded
# Calculations for index: 32080 recorded
# Calculations for index: 32100 recorded
# Calculations for index: 32120 recorded
# Calculations for index: 32140 recorded
# Calculations for index: 32160 recorded
# Calculations for index: 32180 recorded
# Calculations for index: 32200 recorded
# Calculations for index: 32220 recorded
# Calculations for index: 32240 recorded
# Calculations for index: 32260 recorded
# Calculations for index: 32280 recorded
# Calculations for index: 32300 recorded
# Calculations for index: 32320 recorded
# Calculations for index: 32340 recorded
# Calculations for index: 32360 recorded
# Calculations for index: 32380 recorded
# Calculations for index: 32400 recorded
# Calculations for index: 32420 recorded
# Calculations for index: 32440 recorded
# Calculations for index: 32460 recorded
# Calculations for index: 32480 recorded
# Calculations for index: 32500 recorded
# Calculations for index: 32520 recorded
# Calculations for index: 32540 recorded
# Calculations for index: 32560 recorded
# Calculations for index: 32580 recorded
# Calculations for index: 32600 recorded
# Calculations for index: 32620 recorded
# Calculations for index: 32640 recorded
# Calculations for index: 32660 recorded
# Calculations for index: 32680 recorded
# Calculations for index: 32700 recorded
# Calculations for index: 32720 recorded
# Calculations for index: 32740 recorded
# Calculations for index: 32760 recorded
# Calculations for index: 32780 recorded
# Calculations for index: 32800 recorded
# Calculations for index: 32820 recorded
# Calculations for index: 32840 recorded
# Calculations for index: 32860 recorded
# Calculations for index: 32880 recorded
# Calculations for index: 32900 recorded
# Calculations for index: 32920 recorded
# Calculations for index: 32940 recorded
# Calculations for index: 32960 recorded
# Calculations for index: 32980 recorded
# Calculations for index: 33000 recorded
# Calculations for index: 33020 recorded
# Calculations for index: 33040 recorded
# Calculations for index: 33060 recorded
# Calculations for index: 33080 recorded
# Calculations for index: 33100 recorded
# Calculations for index: 33120 recorded
# Calculations for index: 33140 recorded
# Calculations for index: 33160 recorded
# Calculations for index: 33180 recorded
# Calculations for index: 33200 recorded
# Calculations for index: 33220 recorded
# Calculations for index: 33240 recorded
# Calculations for index: 33260 recorded
# Calculations for index: 33280 recorded
# Calculations for index: 33300 recorded
# Calculations for index: 33320 recorded
# Calculations for index: 33340 recorded
# Calculations for index: 33360 recorded
# Calculations for index: 33380 recorded
# Calculations for index: 33400 recorded
# Calculations for index: 33420 recorded
# Calculations for index: 33440 recorded
# Calculations for index: 33460 recorded
# Calculations for index: 33480 recorded
# Calculations for index: 33500 recorded
# Calculations for index: 33520 recorded
# Calculations for index: 33540 recorded
# Calculations for index: 33560 recorded
# Calculations for index: 33580 recorded
# Calculations for index: 33600 recorded
# Calculations for index: 33620 recorded
# Calculations for index: 33640 recorded
# Calculations for index: 33660 recorded
# Calculations for index: 33680 recorded
# Calculations for index: 33700 recorded
# Calculations for index: 33720 recorded
# Calculations for index: 33740 recorded
# Calculations for index: 33760 recorded
# Calculations for index: 33780 recorded
# Calculations for index: 33800 recorded
# Calculations for index: 33820 recorded
# Calculations for index: 33840 recorded
# Calculations for index: 33860 recorded
# Calculations for index: 33880 recorded
# Calculations for index: 33900 recorded
# Calculations for index: 33920 recorded
# Calculations for index: 33940 recorded
# Calculations for index: 33960 recorded
# Calculations for index: 33980 recorded
# Calculations for index: 34000 recorded
# Calculations for index: 34020 recorded
# Calculations for index: 34040 recorded
# Calculations for index: 34060 recorded
# Calculations for index: 34080 recorded
# Calculations for index: 34100 recorded
# Calculations for index: 34120 recorded
# Calculations for index: 34140 recorded
# Calculations for index: 34160 recorded
# Calculations for index: 34180 recorded
# Calculations for index: 34200 recorded
# Calculations for index: 34220 recorded
# Calculations for index: 34240 recorded
# Calculations for index: 34260 recorded
# Calculations for index: 34280 recorded
# Calculations for index: 34300 recorded
# Calculations for index: 34320 recorded
# Calculations for index: 34340 recorded
# Calculations for index: 34360 recorded
# Calculations for index: 34380 recorded
# Calculations for index: 34400 recorded
# Calculations for index: 34420 recorded
# Calculations for index: 34440 recorded
# Calculations for index: 34460 recorded
# Calculations for index: 34480 recorded
# Calculations for index: 34500 recorded
# Calculations for index: 34520 recorded
# Calculations for index: 34540 recorded
# Calculations for index: 34560 recorded
# Calculations for index: 34580 recorded
# Calculations for index: 34600 recorded
# Calculations for index: 34620 recorded
# Calculations for index: 34640 recorded
# Calculations for index: 34660 recorded
# Calculations for index: 34680 recorded
# Calculations for index: 34700 recorded
# Calculations for index: 34720 recorded
# Calculations for index: 34740 recorded
# Calculations for index: 34760 recorded
# Calculations for index: 34780 recorded
# Calculations for index: 34800 recorded
# Calculations for index: 34820 recorded
# Calculations for index: 34840 recorded
# Calculations for index: 34860 recorded
# Calculations for index: 34880 recorded
# Calculations for index: 34900 recorded
# Calculations for index: 34920 recorded
# Calculations for index: 34940 recorded
# Calculations for index: 34960 recorded
# Calculations for index: 34980 recorded
# Calculations for index: 35000 recorded
# Calculations for index: 35020 recorded
# Calculations for index: 35040 recorded
# Calculations for index: 35060 recorded
# Calculations for index: 35080 recorded
# Calculations for index: 35100 recorded
# Calculations for index: 35120 recorded
# Calculations for index: 35140 recorded
# Calculations for index: 35160 recorded
# Calculations for index: 35180 recorded
# Calculations for index: 35200 recorded
# Calculations for index: 35220 recorded
# Calculations for index: 35240 recorded
# Calculations for index: 35260 recorded
# Calculations for index: 35280 recorded
# Calculations for index: 35300 recorded
# Calculations for index: 35320 recorded
# Calculations for index: 35340 recorded
# Calculations for index: 35360 recorded
# Calculations for index: 35380 recorded
# Calculations for index: 35400 recorded
# Calculations for index: 35420 recorded
# Calculations for index: 35440 recorded
# Calculations for index: 35460 recorded
# Calculations for index: 35480 recorded
# Calculations for index: 35500 recorded
# Calculations for index: 35520 recorded
# Calculations for index: 35540 recorded
# Calculations for index: 35560 recorded
# Calculations for index: 35580 recorded
# Calculations for index: 35600 recorded
# Calculations for index: 35620 recorded
# Calculations for index: 35640 recorded
# Calculations for index: 35660 recorded
# Calculations for index: 35680 recorded
# Calculations for index: 35700 recorded
# Calculations for index: 35720 recorded
# Calculations for index: 35740 recorded
# Calculations for index: 35760 recorded
# Calculations for index: 35780 recorded
# Calculations for index: 35800 recorded
# Calculations for index: 35820 recorded
# Calculations for index: 35840 recorded
# Calculations for index: 35860 recorded
# Calculations for index: 35880 recorded
# Calculations for index: 35900 recorded
# Calculations for index: 35920 recorded
# Calculations for index: 35940 recorded
# Calculations for index: 35960 recorded
# Calculations for index: 35980 recorded
# Calculations for index: 36000 recorded
# Calculations for index: 36020 recorded
# Calculations for index: 36040 recorded
# Calculations for index: 36060 recorded
# Calculations for index: 36080 recorded
# Calculations for index: 36100 recorded
# Calculations for index: 36120 recorded
# Calculations for index: 36140 recorded
# Calculations for index: 36160 recorded
# Calculations for index: 36180 recorded
# Calculations for index: 36200 recorded
# Calculations for index: 36220 recorded
# Calculations for index: 36240 recorded
# Calculations for index: 36260 recorded
# Calculations for index: 36280 recorded
# Calculations for index: 36300 recorded
# Calculations for index: 36320 recorded
# Calculations for index: 36340 recorded
# Calculations for index: 36360 recorded
# Calculations for index: 36380 recorded
# Calculations for index: 36400 recorded
# Calculations for index: 36420 recorded
# Calculations for index: 36440 recorded
# Calculations for index: 36460 recorded
# Calculations for index: 36480 recorded
# Calculations for index: 36500 recorded
# Calculations for index: 36520 recorded
# Calculations for index: 36540 recorded
# Calculations for index: 36560 recorded
# Calculations for index: 36580 recorded
# Calculations for index: 36600 recorded
# Calculations for index: 36620 recorded
# Calculations for index: 36640 recorded
# Calculations for index: 36660 recorded
# Calculations for index: 36680 recorded
# Calculations for index: 36700 recorded
# Calculations for index: 36720 recorded
# Calculations for index: 36740 recorded
# Calculations for index: 36760 recorded
# Calculations for index: 36780 recorded
# Calculations for index: 36800 recorded
# Calculations for index: 36820 recorded
# Calculations for index: 36840 recorded
# Calculations for index: 36860 recorded
# Calculations for index: 36880 recorded
# Calculations for index: 36900 recorded
# Calculations for index: 36920 recorded
# Calculations for index: 36940 recorded
# Calculations for index: 36960 recorded
# Calculations for index: 36980 recorded
# Calculations for index: 37000 recorded
# Calculations for index: 37020 recorded
# Calculations for index: 37040 recorded
# Calculations for index: 37060 recorded
# Calculations for index: 37080 recorded
# Calculations for index: 37100 recorded
# Calculations for index: 37120 recorded
# Calculations for index: 37140 recorded
# Calculations for index: 37160 recorded
# Calculations for index: 37180 recorded
# Calculations for index: 37200 recorded
# Calculations for index: 37220 recorded
# Calculations for index: 37240 recorded
# Calculations for index: 37260 recorded
# Calculations for index: 37280 recorded
# Calculations for index: 37300 recorded
# Calculations for index: 37320 recorded
# Calculations for index: 37340 recorded
# Calculations for index: 37360 recorded
# Calculations for index: 37380 recorded
# Calculations for index: 37400 recorded
# Calculations for index: 37420 recorded
# Calculations for index: 37440 recorded
# Calculations for index: 37460 recorded
# Calculations for index: 37480 recorded
# Calculations for index: 37500 recorded
# Calculations for index: 37520 recorded
# Calculations for index: 37540 recorded
# Calculations for index: 37560 recorded
# Calculations for index: 37580 recorded
# Calculations for index: 37600 recorded
# Calculations for index: 37620 recorded
# Calculations for index: 37640 recorded
# Calculations for index: 37660 recorded
# Calculations for index: 37680 recorded
# Calculations for index: 37700 recorded
# Calculations for index: 37720 recorded
# Calculations for index: 37740 recorded
# Calculations for index: 37760 recorded
# Calculations for index: 37780 recorded
# Calculations for index: 37800 recorded
# Calculations for index: 37820 recorded
# Calculations for index: 37840 recorded
# Calculations for index: 37860 recorded
# Calculations for index: 37880 recorded
# Calculations for index: 37900 recorded
# Calculations for index: 37920 recorded
# Calculations for index: 37940 recorded
# Calculations for index: 37960 recorded
# Calculations for index: 37980 recorded
# Calculations for index: 38000 recorded
# Calculations for index: 38020 recorded
# Calculations for index: 38040 recorded
# Calculations for index: 38060 recorded
# Calculations for index: 38080 recorded
# Calculations for index: 38100 recorded
# Calculations for index: 38120 recorded
# Calculations for index: 38140 recorded
# Calculations for index: 38160 recorded
# Calculations for index: 38180 recorded
# Calculations for index: 38200 recorded
# Calculations for index: 38220 recorded
# Calculations for index: 38240 recorded
# Calculations for index: 38260 recorded
# Calculations for index: 38280 recorded
# Calculations for index: 38300 recorded
# Calculations for index: 38320 recorded
# Calculations for index: 38340 recorded
# Calculations for index: 38360 recorded
# Calculations for index: 38380 recorded
# Calculations for index: 38400 recorded
# Calculations for index: 38420 recorded
# Calculations for index: 38440 recorded
# Calculations for index: 38460 recorded
# Calculations for index: 38480 recorded
# Calculations for index: 38500 recorded
# Calculations for index: 38520 recorded
# Calculations for index: 38540 recorded
# Calculations for index: 38560 recorded
# Calculations for index: 38580 recorded
# Calculations for index: 38600 recorded
# Calculations for index: 38620 recorded
# Calculations for index: 38640 recorded
# Calculations for index: 38660 recorded
# Calculations for index: 38680 recorded
# Calculations for index: 38700 recorded
# Calculations for index: 38720 recorded
# Calculations for index: 38740 recorded
# Calculations for index: 38760 recorded
# Calculations for index: 38780 recorded
# Calculations for index: 38800 recorded
# Calculations for index: 38820 recorded
# Calculations for index: 38840 recorded
# Calculations for index: 38860 recorded
# Calculations for index: 38880 recorded
# Calculations for index: 38900 recorded
# Calculations for index: 38920 recorded
# Calculations for index: 38940 recorded
# Calculations for index: 38960 recorded
# Calculations for index: 38980 recorded
# Calculations for index: 39000 recorded
# Calculations for index: 39020 recorded
# Calculations for index: 39040 recorded
# Calculations for index: 39060 recorded
# Calculations for index: 39080 recorded
# Calculations for index: 39100 recorded
# Calculations for index: 39120 recorded
# Calculations for index: 39140 recorded
# Calculations for index: 39160 recorded
# Calculations for index: 39180 recorded
# Calculations for index: 39200 recorded
# Calculations for index: 39220 recorded
# Calculations for index: 39240 recorded
# Calculations for index: 39260 recorded
# Calculations for index: 39280 recorded
# Calculations for index: 39300 recorded
# Calculations for index: 39320 recorded
# Calculations for index: 39340 recorded
# Calculations for index: 39360 recorded
# Calculations for index: 39380 recorded
# Calculations for index: 39400 recorded
# Calculations for index: 39420 recorded
# Calculations for index: 39440 recorded
# Calculations for index: 39460 recorded
# Calculations for index: 39480 recorded
# Calculations for index: 39500 recorded
# Calculations for index: 39520 recorded
# Calculations for index: 39540 recorded
# Calculations for index: 39560 recorded
# Calculations for index: 39580 recorded
# Calculations for index: 39600 recorded
# Calculations for index: 39620 recorded
# Calculations for index: 39640 recorded
# Calculations for index: 39660 recorded
# Calculations for index: 39680 recorded
# Calculations for index: 39700 recorded
# Calculations for index: 39720 recorded
# Calculations for index: 39740 recorded
# Calculations for index: 39760 recorded
# Calculations for index: 39780 recorded
# Calculations for index: 39800 recorded
# Calculations for index: 39820 recorded
# Calculations for index: 39840 recorded
# Calculations for index: 39860 recorded
# Calculations for index: 39880 recorded
# Calculations for index: 39900 recorded
# Calculations for index: 39920 recorded
# Calculations for index: 39940 recorded
# Calculations for index: 39960 recorded
# Calculations for index: 39980 recorded
# All Calculations Complete
# Complete

# %% [markdown]
# ## Manual Overwrite

# %% [markdown]
# This cell is a manual overwrite of the sinal file, just for good measure.

# %%
dataIn.to_csv(writeFile, sep=',', index=False) 

print ('Complete')
# Out:
# Complete

# %% [markdown]
# ------------------------

# %% [markdown]
# # Generate the Signal Graphs

# %% [markdown]
# The general recipie is:
#
# 1). Read in a Signal Data file
#
# 2). Extract the plot information
#
# 3). Plot

# %% [markdown]
# ## Read in External Signal File

# %%
GammaFile = input('Signal Rate filename: ')
readFile = signalDataPath(GammaFile)

print (GammaFile)
# Out:
# Signal Rate filename: 10TeVSignal.csv
# 10TeVSignal.csv

# %% [markdown]
# ## Define the plot region and extract plot data

# %% [markdown]
# We plot the Data under the column
#
#     IceCubeData

# %%
rawData = pd.read_csv(signalDataPath(GammaFile))
Filem_X = float(rawData.loc[0,'mX[GeV]'])


#Pull out min / max values

xMin = min(rawData['mA[GeV]'])
xMax = max(rawData['mA[GeV]'])
yMin = min(rawData['Epsilon'])
yMax = max(rawData['Epsilon'])


# Define the dimension of the grid. 
# For an n x n grid, this will pull out the number "n"
gridDim = len(np.unique(rawData['mA[GeV]']))


#########################################
# Create an n x n grid
#########################################
# Logarithmic Spacing
xLogRange = np.logspace(xMin, xMax, gridDim, base = 10)
yLogRange = np.logspace(yMin, yMax, gridDim, base = 10)

xLinRange = np.linspace(xMin, xMax, gridDim)
yLinRange = np.linspace(yMin, yMax, gridDim)

#########################################
# Read in and reshape the Contour data
#########################################
# This reads in contour data as a single column,
#     but we reshape it to a 2D, n x n array to fit the grid

z = [rawData['IceCubeSignal']]
SignalData = np.reshape(z, (len(xLinRange), len(yLinRange)))

print ('Complete')
# Out:
# Complete

# %% [markdown]
# ## Plot the Signal Events

# %%
###############################
# Set the correct units for m_X
###############################
m_XUnit = 'None'
if (Filem_X < 1000):
    m_XDisplay = Filem_X
    m_XUnit = 'GeV'

if (Filem_X >= 1000):
    m_XDisplay = Filem_X * 10**-3
    m_XUnit = 'TeV'
    
    
###############################
# Define X,Y tickmarks
###############################
# xTicks = np.linspace(xMin, xMax, 10)
# yTicks = np.linspace(yMin, yMax, 10)
# xTicks = np.logspace((xMin), (xMax), 7, base = 10)
# yTicks = np.logspace(np.log10(yMin),np.log10(yMax),7, base = 10)
    
###############################
# Actual Plotting Stuff
###############################
fig0 = plt.figure(figsize = (8,6))
ax0 = fig0.add_subplot(111)
# ax0.set_xticks(xTicks)
# ax0.set_yticks(yTicks)

CP = plt.contour(np.log10(xLogRange), np.log10(yLogRange), \
                 np.log10(SignalData.transpose()),\
                 levels=[0,1,2,3]
                )


plt.xlabel(r'$m_A$ $[GeV]$', fontsize = 13)
plt.ylabel(r'$\varepsilon$', fontsize = 13)
plt.suptitle('IceCube Events', fontsize = 14)
plt.title(r'$m_X$ = {0} {1}'.format(m_XDisplay, m_XUnit), loc = 'right', fontsize = 13)
# plt.axis([xMin,xMax,yMin,yMax])
plt.clabel(CP, inline=1, fontsize=12)
plt.colorbar()
plt.grid()
# Out:
# C:\Users\Adam Green\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: RuntimeWarning: divide by zero encountered in log10

# %% [markdown]
# ### Save Figure

# %%
figName = input('Filename: ')

fig0.savefig(signalPlotPath(figName), dpi = 700, bbox_inches = 'tight')
print ('Complete')
# Out:
# Filename: 10TeVSignalPlot.pdf
# Complete

# %%
###############################
# Set the correct units for m_X
###############################
m_XUnit = 'None'
if (Filem_X < 1000):
    m_XDisplay = Filem_X
    m_XUnit = 'GeV'

if (Filem_X >= 1000):
    m_XDisplay = Filem_X * 10**-3
    m_XUnit = 'TeV'
    
    
###############################
# Define X,Y tickmarks
###############################
# xTicks = np.linspace(xMin, xMax, 10)
# yTicks = np.linspace(yMin, yMax, 10)
# xTicks = np.logspace((xMin), (xMax), 7, base = 10)
# yTicks = np.logspace(np.log10(yMin),np.log10(yMax),7, base = 10)
    
###############################
# Actual Plotting Stuff
###############################
fig0 = plt.figure(figsize = (8,6))
ax0 = fig0.add_subplot(111)
# ax0.set_xticks(xTicks)
# ax0.set_yticks(yTicks)

CP = plt.contour(np.log10(xLogRange), np.log10(yLogRange), \
                 np.log10(SignalData.transpose()),\
                 levels=[0,1,2,3,],
                )


plt.xlabel(r'$m_A$ $[GeV]$', fontsize = 13)
plt.ylabel(r'$\varepsilon$', fontsize = 13)
plt.suptitle('IceCube Events', fontsize = 14)
plt.title(r'$m_X$ = {0} {1}'.format(m_XDisplay, m_XUnit), loc = 'right', fontsize = 13)
# plt.axis([xMin,xMax,yMin,yMax])
plt.clabel(CP, inline=1, fontsize=12)
plt.colorbar(CP)
plt.grid()
# Out:
# C:\Users\Adam Green\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: RuntimeWarning: divide by zero encountered in log10

# %%
xData = rawData['mA[GeV]']
yData1 = rawData['Annihilation']
yData2 = rawData['Capture']

plt.plot(np.log10(xData),np.log10(yData1))

print ('Complete')
# Out:
# Complete
